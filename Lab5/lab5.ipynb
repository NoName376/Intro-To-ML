# %%
#Import numpy and Matplotlib modules
import numpy as np
import matplotlib.pyplot as plt
#ignore warning message
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Question 1

# %%
List = [3, 4, 5]
Ara = np.array([3, 4, 5])
row = np.array([[3, 4, 5]])
col = np.array([[3], [4], [5]])

# %%
print(f"List: {np.shape(List)}")
print(f"Array: {Ara.shape}")
print(f"Row: {row.shape}")
print(f"Column: {col.shape}")
# Out:
# List: (3,)
# Array: (3,)
# Row: (1, 3)
# Column: (3, 1)

# %% [markdown]
# # Question 2

# %%
a = np.array([[4,5,6]])
c = np.array([[0,3,6,9]])

# %% [markdown]
# ### 2.1. Compute a + c . What error do you get?

# %%
a + c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 a + c
#
# ValueError: operands could not be broadcast together with shapes (1,3) (1,4)

# %% [markdown]
# I get "ValueError: operands could not be broadcast together with shapes (1,3) (1,4)" error

# %% [markdown]
# ### 2.2. Explain why it happens using the idea of dimension and orientation compatibility.

# %% [markdown]
# In linear algebra, you are only allowed to add vectors of the same dimension and orientation.

# %% [markdown]
# ### 2.3. Add these two vectors without deleting or adding any elements.

# %%
a.T + c
# Out:
# array([[ 4,  7, 10, 13],
#        [ 5,  8, 11, 14],
#        [ 6,  9, 12, 15]])

# %% [markdown]
# # Question 3

# %%
v = np.array([4, 5])
ve = np.array([5, -3])

plt.plot([-6, 6], [0, 0], 'k--')
plt.plot([0, 0], [-6, 6], 'k--')
plt.grid()
plt.plot([0, ve[0]], [0, ve[1]],'r', label = 've1')
plt.axis((-6, 6, -6, 6))

plt.show()

# %% [markdown]
# # Question 4

# %%
v3 = np.array([6, -5, 4])
ve3 = np.array([5, -4, 3])

fig = plt.figure(figsize=plt.figaspect(1))
ax = plt.axes(projection = '3d')
ax.plot([0, ve3[0]], [0, ve3[1]], [0, ve3[2]], linewidth = 3)
ax.plot([0, 0], [-5, 5], [0, 0], 'k--')
ax.plot([0, 0], [0, 0], [-6, 6], 'k--')
ax.plot([-5, 5], [0, 0], [0, 0], 'k--')
plt.show()

# %% [markdown]
# # Question 5

# %%
v1 = np.array([4, -2])
v2 = np.array([3, 5])

# %% [markdown]
# ### 5.1. Compute v3 = v1 + v2 and print v3

# %%
v3 = v1 + v2
v3
# Out:
# array([7, 3])

# %% [markdown]
# ### 5.2. On the same 2D figure, plot all three** vectors v1 , v2 , and v3 from the origin.**

# %%
plt.plot([0, v1[0]], [0, v1[1]], 'b', label = 'v1')
plt.plot([0, v2[0]], [0, v2[1]], 'r', label = 'v2')
plt.plot([0, v3[0]], [0, v3[1]], 'g', label = 'v1+v2')
plt.plot([-8, 8],[0, 0],'k--')
plt.plot([0, 0],[-8, 8],'k--')
plt.legend()
plt.axis('square')
plt.axis((-8, 8, -8, 8 ))
plt.grid()
plt.show()
