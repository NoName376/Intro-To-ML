# %% [markdown]
# # My Title
# ## My Subtitle
# ### My Section

# %% [markdown]
# <div align="center">
#
# # Welcome to My Notebook
# </div>

# %% [markdown]
# ![text](images.webp)

# %% [markdown]
# <img src="images.webp" width="200">

# %% [markdown]
# <table>
#   <tr>
#     <td><img src="images.webp" width="200"></td>
#     <td>This is a Mexican taco.</td>
#   </tr>
# </table>

# %% [markdown]
# <p align="center">
#  <img src="images.webp" width="150">
#  <img src="mac.webp" width="150">
#  <img src="pizza.jpg" width="150">
# </p>

# %% [markdown]
# <center>
#     <h1>This is a Italian pizza</h1>
#     <img src="pizza.jpg" width="300">
# </center>
