# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3

# %% [markdown]
# <div align="center">
#
# # Centered text
# </div>

# %% [markdown]
# <h1 align="center">Centered Heading</h1>

# %% [markdown]
# **bold text**
# *italic text*

# %% [markdown]
# - Vegetables
# - Fruits
#  - Apple

# %% [markdown]
# 1. Open site
# 2. Install Anaconda
# 3. Run Navigator

# %% [markdown]
# [Python](https://www.python.org/)
# Example: Python

# %% [markdown]
# ![text](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRp4JCgVbHjC4h-SN69mQn5Y-b6F-JVXlxtGg&s)
# Example: Notre-dame

# %% [markdown]
# <img src="images.webp" width="200">

# %% [markdown]
# <table>
# <tr>
# <td><img src="images.webp" width="150"></td>
# <td>This image represents how robot is learning.</td>
# </tr>
# </table>

# %% [markdown]
# <p align="center">
#  <img src="images.webp" width="150">
#  <img src="mac.webp" width="150">
#  <img src="pizza.jpg" width="150">
# </p>

# %% [markdown]
# ```python
# def hello():
#  print("Hello, Jupyter!")

# %% [markdown]
# | Name | Age | Country |
# |-------|-----|---------|
# | Karim | 17 | Kazakhstan |
# | Ansar | 18 | Kazakhstan |

# %% [markdown]
# ---

# %% [markdown]
# > a blockquote.
# > Use for highlight tips

# %% [markdown]
# 1. C#
#  - Windows apps
#  - GameDev
# 2. C++
#  - Virus
#  - Native apps

# %% [markdown]
# This is an inline formula: $F = ma$
# Block math:
# $$
# \int_0^1 (x + 3) dx = \frac{1}{3}
# $$

# %% [markdown]
# ~~Use java for frontend~~
# Example:
# Use java for backend

# %% [markdown]
#  [x] Do lab1
# - [ ] Do lab2
# - [ ] Go to sleep

# %% [markdown]
# <p style="color:yellow;">This text is yellow</p>
# Example:

# %% [markdown]
# 🤖 My ML Journey
#
# I’m really excited 😍 to dive into machine learning and AI!
# Every day I want to 🚀 improve my skills and master new algorithms.
# I’ll keep practicing 👍 building models and analyzing data to get better results.
# Sometimes it’s challenging ⚠️, but learning from mistakes ❌ makes me stronger.
# My goal is to create 🔥 innovative solutions that can make a real impact 🌍.
# Let’s keep going! 🙌

# %% [markdown]
# ## ✅ ML Study Plan
#
#  Understand supervised learning 📚
#
#  Implement regression models 📈
#
#  Explore neural networks 🤖
#
#  Practice with real datasets 🧑‍💻
#
#  Tune hyperparameters 🔧
#
#  Deploy a simple ML app 🚀
